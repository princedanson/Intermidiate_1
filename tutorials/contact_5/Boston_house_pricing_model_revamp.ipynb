# %% [markdown]
# <a href="https://colab.research.google.com/github/princedanson/Intermidiate_1/blob/main/tutorials/contact_5/Boston_house_pricing_model_revamp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import (LinearRegression,Ridge,Lasso,ElasticNet)
from sklearn.preprocessing import (PolynomialFeatures, StandardScaler,PowerTransformer)
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (mean_absolute_error,mean_squared_error,
                             root_mean_squared_error,accuracy_score,r2_score)

# %%
#fetching the datsa and target
boston = fetch_openml(name='boston', version=1, as_frame=True)
y = boston.target
x = boston.data

# %%
x
# Out:
#         CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS RAD    TAX  \
# 0    0.00632  18.0   2.31    0  0.538  6.575  65.2  4.0900   1  296.0
# 1    0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671   2  242.0
# 2    0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671   2  242.0
# 3    0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622   3  222.0
# 4    0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622   3  222.0
# ..       ...   ...    ...  ...    ...    ...   ...     ...  ..    ...
# 501  0.06263   0.0  11.93    0  0.573  6.593  69.1  2.4786   1  273.0
# 502  0.04527   0.0  11.93    0  0.573  6.120  76.7  2.2875   1  273.0
# 503  0.06076   0.0  11.93    0  0.573  6.976  91.0  2.1675   1  273.0
# 504  0.10959   0.0  11.93    0  0.573  6.794  89.3  2.3889   1  273.0
# 505  0.04741   0.0  11.93    0  0.573  6.030  80.8  2.5050   1  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
pipeline = {
    'Linear Regression':Pipeline([
        ("PowerTransformer", PowerTransformer()),
        ("StandardScaler", StandardScaler()),
        ("PolynomialFeatures", PolynomialFeatures(degree=2)),
        ("Model", LinearRegression())]),
    "Ridge": Pipeline([
        ("PowerTransformer", PowerTransformer()),
        ("StandardScaler", StandardScaler()),
        ("PolynomialFeatures", PolynomialFeatures(degree=2)),
        ('Model', Ridge())]),
    "Lasso":Pipeline([
        ("PowerTransformer", PowerTransformer()),
        ("StandardScaler", StandardScaler()),
        ("PolynomialFeatures", PolynomialFeatures(degree=2)),
        ('Model', Lasso())]),
    "ElasticNet":Pipeline([
        ("PowerTransformer", PowerTransformer()),
        ("StandardScaler", StandardScaler()),
        ("PolynomialFeatures", PolynomialFeatures(degree=2)),
        ("Model", ElasticNet())])
}

# %%
result = {}

# %%
for Model_name, model in pipeline.items():
    model.fit(x_train,y_train)
    pred = model.predict(x_test)

    model_mae = mean_absolute_error(y_test,pred)
    model_mse = mean_squared_error(y_test,pred)
    model_rmse = root_mean_squared_error(y_test,pred)
    model_test = r2_score(y_test,pred)
    model_train = r2_score(y_train,model.predict(x_train))
    model_loss = pred.std()
    result[Model_name] = model_test

    print(f"{Model_name}:")
    print(f"Train R2 Score: {model_train:.4f}")
    print(f"Test R2 Score: {model_test:.4f}")
    print(f"MAE: {model_mae:.4f}")
    print(f"MSE: {model_mse:.4f}")
    print(f"RMSE: {model_rmse:.4f}")
    print(f"Loss: {model_loss:.4f}")
    print("-"*30)
# Out:
# Linear Regression:
# Train R2 Score: 0.9432
# Test R2 Score: 0.8216
# MAE: 2.4282
# MSE: 13.0799
# RMSE: 3.6166
# Loss: 8.4552
# ------------------------------
# Ridge:
# Train R2 Score: 0.9422
# Test R2 Score: 0.8220
# MAE: 2.3068
# MSE: 13.0565
# RMSE: 3.6134
# Loss: 8.3977
# ------------------------------
# Lasso:
# Train R2 Score: 0.7933
# Test R2 Score: 0.7405
# MAE: 2.8019
# MSE: 19.0308
# RMSE: 4.3624
# Loss: 6.3841
# ------------------------------
# ElasticNet:
# Train R2 Score: 0.8007
# Test R2 Score: 0.7293
# MAE: 2.7852
# MSE: 19.8493
# RMSE: 4.4553
# Loss: 5.9219
# ------------------------------

# %%
    best_model = max(result, key=result.get)
    print(f"Best Model: {best_model}")
# Out:
# Best Model: Ridge
