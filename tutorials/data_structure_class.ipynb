# %%
import  numpy  as np
import pandas as pd

# %%
s = pd.Series(np.random.randn(5), index = ['a','b','c','d','e'])
s
# Out:
# a    0.903102
# b    1.426644
# c    0.226277
# d    0.196501
# e   -0.191690
# dtype: float64

# %%
s = pd.Series(np.random.randn(5)*10)
s
# Out:
# 0    -9.650956
# 1    -3.576100
# 2     7.979713
# 3   -12.051159
# 4   -18.646525
# dtype: float64

# %%
s.iloc[0]
# Out:
# np.float64(-9.650955685326148)

# %%
s.iloc[:3]
# Out:
# 0   -9.650956
# 1   -3.576100
# 2    7.979713
# dtype: float64
